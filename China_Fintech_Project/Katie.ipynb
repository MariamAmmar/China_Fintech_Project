# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
file = 'data/county.xlsx'

# %%
data = pd.read_excel(file)
data = data.copy()
data.shape
# Out:
# (9120, 24)

# %%
data.shape
# Out:
# (9120, 24)

# %%
df = data.copy()

# %%
# df_2018 = data[data.year==2018]
# df_2017 = data[data.year==2017]
# df_2016 = data[data.year==2016]
# df_2015 = data[data.year==2015]
# df_2014 = data[data.year==2014]

# %%
# print("2018",df_2018.shape)
# print("2017",df_2017.shape)
# print("2016",df_2016.shape)
# print("2015",df_2015.shape)
# print("2014",df_2014.shape)

# %%
# print("2018",df_2018.isnull().sum())
# print("2017",df_2017.isnull().sum())
# print("2016",df_2016.isnull().sum())
# print("2015",df_2015.isnull().sum())
# print("2014",df_2014.isnull().sum())

# %%
# df_2018.isnull().sum()/1898

# %%
# #Importing the function
# from pandas_profiling import ProfileReport
# #Generate the report
# profile = ProfileReport(df=df_2018, title=' Pandas Profiling Report', explorative = True)
# profile

# %%
# df_2018[df_2018.county_name=="崇明县"]
# df_2018[df_2018.prov_name=="重庆市"].head(1)

# %%
# df_2018.gdp.isnull().sum()

# %%
# df_2017.gdp.isnull().sum()

# %%
# # creating bool series True for NaN values  
# bool_series = pd.isnull(df_2017["gdp"])  
    
# # filtering data  
# # displaying data only with Gender = NaN  
# df_2017[bool_series]

# %%
# df_2017.columns

# %%
data.county_code_year14.isnull().sum()
# Out:
# 0

# %%
# df_2018.sort_values("index_aggregate", ascending = False).head(10)

# %%
# In Python
# from sklearn.preprocessing import Imputer
# values = mydata.values
# imputer = Imputer(missing_values=’NaN’, strategy=’mean’)
# transformed_values = imputer.fit_transform(values)
# # strategy can be changed to "median" and “most_frequent”

# %%
# import numpy as np
# from sklearn.impute import SimpleImputer
# gdp = df_2018[["gdp"]]
# imp = SimpleImputer(missing_values=np.nan, strategy='median')
# df_2018[["gdp"]] = imp.fit_transform(gdp)
# # strategy can be changed to "median" and “most_frequent”

# %%
# df_2018.columns

# %%
# df_2018.iloc[:,8:].dtypes

# %%
# imp = SimpleImputer(missing_values=np.nan, strategy='median')
# df_2018.iloc[:,8:]= imp.fit_transform(df_2018.iloc[:,8:])

# %%
# df_2018 = df_2018.fillna(lambda x: x.median())

# %%
# df_2018.isnull().sum()

# %%
df.loc[df['year'] == 2014, 'credit_investigation'] = 0

# %%
df[df.year==2014]["credit_investigation"].unique()
# Out:
# array([0.])

# %%
df.isnull().sum()
# Out:
# year                       0
# county_name                0
# county_code_year14         0
# prov_code                  0
# prov_name                  0
# pref_code                  0
# pref_name                  1
# index_aggregate            0
# coverage_breadth           0
# usage_depth                0
# payment                    0
# insurance                  0
# monetary_fund              0
# investment                 0
# credit                     0
# credit_investigation       0
# digitization_level         0
# flb                     1263
# gdp                      520
# per_gdp                 3005
# urban                   6034
# industry                6052
# ip                      7558
# tradeopeness            6996
# dtype: int64

# %%
df.shape
# Out:
# (9120, 24)

# %%
# should start with 19th columns on per_gdp
import numpy as np
from sklearn.impute import SimpleImputer
def imputer(df):
    imp = SimpleImputer(missing_values=np.nan, strategy='median')
    df.iloc[:,19:] = imp.fit_transform(df.iloc[:,19:])
    return df

for i in df.year.value_counts().index:
    df[df.year==i] = imputer(df[df.year==i])
df.head()
# Out:
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# county_name                0
# county_code_year14         0
# prov_code                  0
# prov_name                  0
# pref_code                  0
# pref_name                  1
# index_aggregate            0
# coverage_breadth           0
# usage_depth                0
# payment                    0
# insurance                  0
# monetary_fund              0
# investment                 0
# credit                     0
# credit_investigation       0
# digitization_level         0
# flb                     1263
# gdp                      520
# per_gdp                    0
# urban                      0
# industry                   0
# ip                         0
# tradeopeness               0
# dtype: int64

# %%
df.shape
# Out:
# (9120, 24)

# %%
bool_series = pd.isnull(df["pref_name"])  
    
# filtering data  
# displaying data only with Gender = NaN  
df[bool_series]
# Out:
#       year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 7850  2018        尼勒克县              654028         65  新疆维吾尔自治区       6540
#
#      pref_name  index_aggregate  coverage_breadth  usage_depth  ...  credit  \
# 7850       NaN            90.04             84.31         94.4  ...  102.75
#
#       credit_investigation  digitization_level  flb  gdp  per_gdp     urban  \
# 7850                 95.81              101.03  NaN  NaN  34697.0  0.230346
#
#       industry        ip  tradeopeness
# 7850   0.26967  0.193353      0.237948
#
# [1 rows x 24 columns]

# %%
df[df["pref_code"]==6540].head(1)
# Out:
#      year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 150  2014         伊宁县              654021         65  新疆维吾尔自治区       6540
#
#     pref_name  index_aggregate  coverage_breadth  usage_depth  ...  credit  \
# 150  伊犁哈萨克自治州            19.75             10.25        32.61  ...   42.11
#
#      credit_investigation  digitization_level       flb       gdp  per_gdp  \
# 150                   0.0               27.76  710412.0  691583.0  15927.0
#
#         urban  industry        ip  tradeopeness
# 150  0.176879  0.201927  0.106056      0.031628
#
# [1 rows x 24 columns]

# %%
df.at[7850,"pref_name"] = "伊犁哈萨克自治州"

# %%
df.isnull().sum()
# Out:
# year                       0
# county_name                0
# county_code_year14         0
# prov_code                  0
# prov_name                  0
# pref_code                  0
# pref_name                  0
# index_aggregate            0
# coverage_breadth           0
# usage_depth                0
# payment                    0
# insurance                  0
# monetary_fund              0
# investment                 0
# credit                     0
# credit_investigation       0
# digitization_level         0
# flb                     1263
# gdp                      520
# per_gdp                    0
# urban                      0
# industry                   0
# ip                         0
# tradeopeness               0
# dtype: int64

# %%
df.shape
# Out:
# (9120, 24)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
def imputer(df):
    imp = SimpleImputer(missing_values=np.nan, strategy='median')
    df.iloc[:,17:18] = imp.fit_transform(df.iloc[:,17:18])
    return df

for i in df.year.value_counts().index:
    df[df.year==i] = imputer(df[df.year==i])
df.head()
# Out:
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# ...

# %%
df.isnull().sum()
# Out:
# year                      0
# county_name               0
# county_code_year14        0
# prov_code                 0
# prov_name                 0
# pref_code                 0
# pref_name                 0
# index_aggregate           0
# coverage_breadth          0
# usage_depth               0
# payment                   0
# insurance                 0
# monetary_fund             0
# investment                0
# credit                    0
# credit_investigation      0
# digitization_level        0
# flb                       0
# gdp                     520
# per_gdp                   0
# urban                     0
# industry                  0
# ip                        0
# tradeopeness              0
# dtype: int64

# %%
df.shape
# Out:
# (9120, 24)

# %%
# df.to_csv("data/imputer_fintech.csv")

# %%
# gdp_df = pd.read_csv("data/gdp.csv")

# %%
# gdp_df

# %%
# add new column ,increase percentage
# gdp_df["increase_percent"] = gdp_df["2018"]/gdp_df["2017"]

# %%
# gdp_df

# %%
# clean_df = pd.read_csv("data/clean_fintech.csv")

# %%
# gdp_df.to_csv("data/gdp.csv",index=False)

# %%
# gdp = pd.read_csv("data/gdp.csv")

# %%
# gdp.Area = gdp.Area+ "省"

# %%
# gdp.at[0,"Area"] = "新疆维吾尔自治区"
# gdp.at[1,"Area"] = "宁夏回族自治区"
# gdp.at[5,"Area"] = '西藏自治区'
# gdp.at[9,"Area"] = '广西壮族自治区'
# gdp.at[22,"Area"] = '内蒙古自治区'

# %%
# gdp

# %%
# df[["prov_code","prov_name"]].nunique()

# %%
# from collections import Counter
# list(set(df[["prov_code","prov_name"]]))

# %%
# list(set(df["prov_name"]))
# list(set(df["prov_code"]))

# %%
# column_values = df[["prov_code","prov_name"]].values.ravel()
# unique_values =  pd.unique(column_values)
# unique_values

# %%
# prov_map = {}
# for i in range(0,len(unique_values),2):
#     prov_map[unique_values[i+1]] = unique_values[i]

# %%
# prov_map

# %%
# gdp["Area_code"] = gdp.Area.map(prov_map)

# %%
# gdp.to_csv("data/gdp.csv",index=False)

# %%
# new_gdp = pd.read_csv("data/gdp.csv")

# %%
# new_gdp.rename(columns={"Area":"prov_name","Area_code":"prov_code"},inplace=True)

# %%
# new_gdp
# new_gdp.to_csv("data/gdp.csv",index=False)

# %%
# in_gdp = new_gdp[["increase_percent","prov_code"]]
# in_gdp

# %%
# df = df.merge(in_gdp, on="prov_code")

# %%
# df[df.year==2018].isnull().sum()

# %%
# df[df.year==2017].isnull().sum()

# %%
# bool_series = pd.isnull(df[df.year==2018]["gdp"])  
    
# # filtering data  
# # displaying data only with gdp = NaN
# df[df.year==2018][bool_series]

# %%
# missing_df = df[df.year==2018][bool_series] 
# missing_df.head()

# %%
gdp = pd.read_csv("data/gdp.csv")

# %%
gdp.head()
# Out:
#   prov_name      2017      2018  increase_percent  prov_code
# 0  新疆维吾尔自治区  10881.96  12809.39          1.177122         65
# 1   宁夏回族自治区   3443.56   3510.21          1.019355         64
# 2       青海省   2624.83   2748.00          1.046925         63
# 3       甘肃省   7459.90   8104.07          1.086351         62
# 4       陕西省  21898.81  23941.88          1.093296         61

# %%
in_gdp = gdp[["increase_percent","prov_code"]]
in_gdp.head()
df = df.merge(in_gdp, on="prov_code",how="left")

# %%
df.shape
# Out:
# (9120, 25)

# %%
df.isnull().sum()
# Out:
# year                      0
# county_name               0
# county_code_year14        0
# prov_code                 0
# prov_name                 0
# pref_code                 0
# pref_name                 0
# index_aggregate           0
# coverage_breadth          0
# usage_depth               0
# payment                   0
# insurance                 0
# monetary_fund             0
# investment                0
# credit                    0
# credit_investigation      0
# digitization_level        0
# flb                       0
# gdp                     520
# per_gdp                   0
# urban                     0
# industry                  0
# ip                        0
# tradeopeness              0
# increase_percent          0
# dtype: int64

# %%
df.shape
# Out:
# (9120, 25)

# %%
# def fill_2018(df):
#     imp = SimpleImputer(missing_values=np.nan, strategy='median')
#     df.iloc[:,17:18] = imp.fit_transform(df.iloc[:,17:18])
#     return df

# for i in df.year.value_counts().index:
#     df[df.year==i] = imputer(df[df.year==i])
# df.head()

# %%
bool_series = pd.isnull(df[df.year==2018]["gdp"])  
    
# filtering data  
# displaying data only with gdp = NaN
df[df.year==2018][bool_series]
# Out:
#       year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 7355  2018     互助土族自治县              630223         63       青海省       6302
# 7357  2018         五原县              150821         15    内蒙古自治区       1508
# 7365  2018         五莲县              371121         37       山东省       3711
# 7366  2018        井冈山市              360881         36       江西省       3608
# 7368  2018         井陉县              130121         13       河北省       1301
# ...    ...         ...                 ...        ...       ...        ...
# 9099  2018         黎川县              361022         36       江西省       3610
# 9101  2018         黑山县              210726         21       辽宁省       2107
# 9105  2018         齐河县              371425         37       山东省       3714
# 9107  2018         龙南县              360727         36       江西省       3607
# 9108  2018         龙口市              370681         37       山东省       3706
#
# ...

# %%
bool_series = pd.isnull(df[df.year==2018]["increase_percent"])  
    
# filtering data  
# displaying data only with gdp = NaN
df[df.year==2018][bool_series]
# Out:
# Empty DataFrame
# Columns: [year, county_name, county_code_year14, prov_code, prov_name, pref_code, pref_name, index_aggregate, coverage_breadth, usage_depth, payment, insurance, monetary_fund, investment, credit, credit_investigation, digitization_level, flb, gdp, per_gdp, urban, industry, ip, tradeopeness, increase_percent]
# Index: []
#
# [0 rows x 25 columns]

# %%
for i, row in df.iterrows():
    try:
        if (row["year"]==2018) and np.isnan(row["gdp"]):
            df.loc[i,"gdp"] = (df[(df.county_code_year14 == row["county_code_year14"]) & (df.year==2017)].gdp 
                         * row["increase_percent"]).values[0]
#             print(df.iloc[i,:])
#             break
    except IndexError:
        print(i, row)
# Out:
# 7355 year                        2018
# county_name              互助土族自治县
# county_code_year14        630223
# prov_code                     63
# prov_name                    青海省
# pref_code                   6302
# pref_name                    海东市
# index_aggregate            81.83
# coverage_breadth           71.59
# usage_depth                97.48
# payment                    34.35
# insurance                  83.89
# monetary_fund              46.23
# investment                 138.6
# credit                      94.9
# credit_investigation       85.98
# digitization_level         87.24
# flb                      1.2e+06
# gdp                          NaN
# per_gdp                    34697
# urban                   0.324884
# industry                 0.26967
# ip                      0.193353
# tradeopeness            0.237948
# increase_percent         1.04692
# Name: 7355, dtype: object
# 7369 year                        2018
# county_name                  亚东县
# ...

# %%
# try:
#     for row in df[df.year==2018][bool_series].iterrows():
#         row[1]["gdp"] = (df[(df.county_code_year14 == row[1]["county_code_year14"]) & (df.year==2017)].gdp 
#                          * row[1]["increase_percent"]).values[0]
#         print(row)
#         break
# except IndexError:
#     print(row)

# %%
df[(df.year ==2017) & (df.county_code_year14 == 130729)]
# Out:
#       year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 5335  2017         万全县              130729         13       河北省       1307
#
#      pref_name  index_aggregate  coverage_breadth  usage_depth  ...  \
# 5335      张家口市            99.18             92.04       115.36  ...
#
#       credit_investigation  digitization_level       flb       gdp  per_gdp  \
# 5335                122.25               93.38  624922.0  666736.0  32202.0
#
#        urban  industry        ip  tradeopeness  increase_percent
# 5335  0.2538  0.287401  0.197952      0.025868          0.955265
#
# [1 rows x 25 columns]

# %%
df[(df.year ==2018) & (df.county_code_year14 == 130729)]
# Out:
#       year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 7222  2018         万全县              130729         13       河北省       1307
#
#      pref_name  index_aggregate  coverage_breadth  usage_depth  ...  \
# 7222      张家口市           100.18             89.78       115.81  ...
#
#       credit_investigation  digitization_level        flb            gdp  \
# 7222                112.42              106.13  1200000.0  636909.762519
#
#       per_gdp     urban  industry        ip  tradeopeness  increase_percent
# 7222  34697.0  0.324884   0.26967  0.193353      0.237948          0.955265
#
# [1 rows x 25 columns]

# %%
np.isnan(df[(df.year ==2018) & (df.county_code_year14 == 130729)]['gdp'].values[0])
# Out:
# False

# %%
df[(df.year ==2017) & (df.county_code_year14 == 630223)]
# Out:
# Empty DataFrame
# Columns: [year, county_name, county_code_year14, prov_code, prov_name, pref_code, pref_name, index_aggregate, coverage_breadth, usage_depth, payment, insurance, monetary_fund, investment, credit, credit_investigation, digitization_level, flb, gdp, per_gdp, urban, industry, ip, tradeopeness, increase_percent]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.shape
# Out:
# (9120, 25)

# %%
df.isnull().sum()
# Out:
# year                     0
# county_name              0
# county_code_year14       0
# prov_code                0
# prov_name                0
# pref_code                0
# pref_name                0
# index_aggregate          0
# coverage_breadth         0
# usage_depth              0
# payment                  0
# insurance                0
# monetary_fund            0
# investment               0
# credit                   0
# credit_investigation     0
# digitization_level       0
# flb                      0
# gdp                     41
# per_gdp                  0
# urban                    0
# industry                 0
# ip                       0
# tradeopeness             0
# increase_percent         0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
def imputer(df):
    imp = SimpleImputer(missing_values=np.nan, strategy='median')
    df.iloc[:,18:19] = imp.fit_transform(df.iloc[:,18:19])
    return df

for i in df.year.value_counts().index:
    df[df.year==i] = imputer(df[df.year==i])
df.head()
# Out:
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /Users/katie/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# ...

# %%
df.isnull().sum()
# Out:
# year                    0
# county_name             0
# county_code_year14      0
# prov_code               0
# prov_name               0
# pref_code               0
# pref_name               0
# index_aggregate         0
# coverage_breadth        0
# usage_depth             0
# payment                 0
# insurance               0
# monetary_fund           0
# investment              0
# credit                  0
# credit_investigation    0
# digitization_level      0
# flb                     0
# gdp                     0
# per_gdp                 0
# urban                   0
# industry                0
# ip                      0
# tradeopeness            0
# increase_percent        0
# dtype: int64

# %%
df.shape
# Out:
# (9120, 25)

# %%
df.drop(columns =["increase_percent"],inplace=True)

# %%
df.shape
# Out:
# (9120, 24)

# %%
df.to_csv("data/gdp_clean_fintech.csv",index=False)

# %%
df.head()
# Out:
#    year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 0  2014         万全县              130729         13       河北省       1307
# 1  2014         万安县              360828         36       江西省       3608
# 2  2014         万年县              361129         36       江西省       3611
# 3  2014         万源市              511781         51       四川省       5117
# 4  2014         万荣县              140822         14       山西省       1408
#
#   pref_name  index_aggregate  coverage_breadth  usage_depth  ...  credit  \
# 0      张家口市            44.58             52.42        37.77  ...   35.34
# 1       吉安市            44.39             33.21        78.26  ...   85.27
# 2       上饶市            47.34             42.86        60.84  ...   57.87
# 3       达州市            41.67             46.64        41.19  ...   45.24
# 4       运城市            45.07             48.69        44.57  ...   62.17
#
#    credit_investigation  digitization_level       flb        gdp  per_gdp  \
# ...

# %%
data.head()
# Out:
#    year county_name  county_code_year14  prov_code prov_name  pref_code  \
# 0  2014         万全县              130729         13       河北省       1307
# 1  2014         万安县              360828         36       江西省       3608
# 2  2014         万年县              361129         36       江西省       3611
# 3  2014         万源市              511781         51       四川省       5117
# 4  2014         万荣县              140822         14       山西省       1408
#
#   pref_name  index_aggregate  coverage_breadth  usage_depth  ...  credit  \
# 0      张家口市            44.58             52.42        37.77  ...   35.34
# 1       吉安市            44.39             33.21        78.26  ...   85.27
# 2       上饶市            47.34             42.86        60.84  ...   57.87
# 3       达州市            41.67             46.64        41.19  ...   45.24
# 4       运城市            45.07             48.69        44.57  ...   62.17
#
#    credit_investigation  digitization_level       flb        gdp  per_gdp  \
# ...
